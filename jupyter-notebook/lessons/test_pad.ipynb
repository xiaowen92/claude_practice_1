# %%
from IPython.display import Markdown, display
output1 = '''

"# Solution: Total Sales Grouped by Product\n\nHere are several ways to solve this:\n\n## **Method 1: Using `groupby()` (Recommended)**\n\n```python\nimport pandas as pd\n\n# Sample DataFrame\ndf = pd.DataFrame({\n    'product': ['A', 'B', 'A', 'C', 'B', 'A'],\n    'sales': [100, 150, 200, 75, 120, 50]\n})\n\n# Group by product and sum sales\nresult = df.groupby('product')['sales'].sum()\nprint(result)\n```\n\n**Output:**\n```\nproduct\nA    350\nB    270\nC     75\nName: sales, dtype: int64\n```\n\n## **Method 2: Return as DataFrame**\n\n```python\nresult = df.groupby('product')['sales'].sum().reset_index()\nprint(result)\n```\n\n**Output:**\n```\n  product  sales\n0       A    350\n1       B    270\n2       C     75\n```\n\n## **Method 3: Using `agg()` for more flexibility**\n\n```python\nresult = df.groupby('product').agg({'sales': 'sum'})\nprint(result)\n```\n\n## **Method 4: Sort by sales (descending)**\n\n```python\nresult = df.groupby('product')['sales'].sum().sort_values(ascending=False)\nprint(result)\n```\n\n**Output:**\n```\nproduct\nA    350\nB    270\nC     75\nName: sales, dtype: int64\n```\n\n---\n\n### **Key Points:**\n- **`groupby('product')`** - Groups rows by product name\n- **`['sales'].sum()`** - Sums the sales for each group\n- **`reset_index()`** - Converts Series to DataFrame (useful for further processing)\n- **`sort_values()`** - Orders results by sales amount\n\nChoose **Method 1** for most use cases, or **Method 2** if you need a DataFrame format."

'''
display(Markdown(output1))
# Out:
# "# Solution: Total Sales Grouped by Product
#
# Here are several ways to solve this:
#
# ## **Method 1: Using `groupby()` (Recommended)**
#
# ```python
# import pandas as pd
#
# # Sample DataFrame
# df = pd.DataFrame({
#     'product': ['A', 'B', 'A', 'C', 'B', 'A'],
#     'sales': [100, 150, 200, 75, 120, 50]
# })
#
# # Group by product and sum sales
# result = df.groupby('product')['sales'].sum()
# print(result)
# ```
#
# **Output:**
# ```
# product
# A    350
# B    270
# C     75
# Name: sales, dtype: int64
# ```
#
# ## **Method 2: Return as DataFrame**
#
# ```python
# result = df.groupby('product')['sales'].sum().reset_index()
# print(result)
# ```
#
# **Output:**
# ```
#   product  sales
# 0       A    350
# 1       B    270
# 2       C     75
# ```
#
# ## **Method 3: Using `agg()` for more flexibility**
#
# ```python
# result = df.groupby('product').agg({'sales': 'sum'})
# print(result)
# ```
#
# ## **Method 4: Sort by sales (descending)**
#
# ```python
# ...
